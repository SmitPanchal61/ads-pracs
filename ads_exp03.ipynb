# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Reliance_Data_Mart=pd.read_excel(r'/content/drive/MyDrive/ads_dataset/RelianceDataMart.xlsx')
Reliance_Data_Mart
# Out:
#     Rice_Bag_Weight
# 0             24.50
# 1             24.70
# 2             25.60
# 3             25.00
# 4             24.70
# 5             23.30
# 6             23.30
# 7             24.00
# 8             25.10
# 9             24.30
# 10            23.30
# 11            24.10
# 12            24.10
# 13            24.20
# 14            25.20
# 15            24.90
# 16            24.70
# 17            24.10
# 18            25.00
# 19            24.70
# 20            24.90
# 21            25.00
# 22            24.00
# 23            23.98
# 24            24.30
# 25            24.20
# 26            24.56
# 27            24.50
# 28            24.70

# %%
Reliance_Data_Mart.describe()
# Out:
#        Rice_Bag_Weight
# count        29.000000
# mean         24.446207
# std           0.569463
# min          23.300000
# 25%          24.100000
# 50%          24.500000
# 75%          24.900000
# max          25.600000

# %%
one_sample_result=stats.ttest_1samp(Reliance_Data_Mart,25)
one_sample_result
# Out:
# TtestResult(statistic=array([-5.23697685]), pvalue=array([1.45121657e-05]), df=array([28]))

# %%
one_sample_result1=stats.ttest_1samp(Reliance_Data_Mart,24.235)
one_sample_result1
# Out:
# TtestResult(statistic=array([1.99729036]), pvalue=array([0.05559509]), df=array([28]))

# %% [markdown]
# Conclusion = One sample t-test has been done on the reliance data mart dataset and it has been found that difference exists between the rice
# bag population mean and rice bag sample mean

# %%
PrePostScore=pd.read_excel(r'/content/drive/MyDrive/Pre_Post_Score.xlsx')
PrePostScore
# Out:
#     Pre_Score  Post_Score
# 0          18          22
# 1          21          25
# 2          16          17
# 3          22          24
# 4          19          16
# 5          24          29
# 6          17          20
# 7          21          23
# 8          23          19
# 9          18          20
# 10         14          15
# 11         16          15
# 12         16          18
# 13         19          26
# 14         18          18
# 15         20          24
# 16         12          18
# 17         22          25
# 18         15          19
# 19         17          16

# %%
Two_Sample_Result=stats.ttest_rel(PrePostScore["Pre_Score"],PrePostScore["Post_Score"])
Two_Sample_Result
# Out:
# TtestResult(statistic=-3.231252665580312, pvalue=0.004394965993185664, df=19)

# %% [markdown]
# Conclusion:Two sample paired t-test has been done on the prescore-post score dataset.Since the difference occurs between the calculated value and critical value, therefore there exists a difference between the score before learning the module and after learning the module.

# %%
Crocin=pd.read_excel(r'/content/drive/MyDrive/Crocin_Data_ST.xlsx')
Crocin
# Out:
#     Before_Crocin  After_Crocin
# 0           101.0            99
# 1            99.0            98
# 2           101.0            97
# 3            99.9            99
# 4            99.8            98
# 5            98.0            97
# 6            97.0            99
# 7           101.0            98
# 8           102.0            96
# 9           103.0            98
# 10           99.0            94
# 11           99.9            96
# 12           99.8            97
# 13           99.7            99
# 14          101.1            98
# 15          102.3            97
# 16          101.0            99
# 17           99.0            98
# 18          101.0            97
# 19           99.9            99
# 20           99.8            98
# 21           98.0            96
# 22           97.0            97
# 23          101.0            99
# 24          102.0            97
# 25          103.0            99
# 26           99.0            98
# 27           99.9            97
# ...

# %%
Two_Sample_Result=stats.ttest_rel(Crocin["Before_Crocin"],Crocin["After_Crocin"])
Two_Sample_Result
# Out:
# TtestResult(statistic=7.071712959273876, pvalue=1.0800112658101922e-07, df=28)

# %% [markdown]
# Conclusion:Two sample paired t-test has been done on the Crocin dataset. In the crocin dataset it is found that temperature difference exists before and after having the crocin tablet.
